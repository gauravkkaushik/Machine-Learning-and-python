# %%
# !pip install dist/dataudit-0.1.0.tar.gz
# Out:
# Processing .\dist\dataudit-0.1.0.tar.gz
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy<2,>=1.23 in C:\Users\gaura\anaconda3\Lib\site-packages (from dataudit==0.1.0) (1.26.4)
# Requirement already satisfied: pandas>=1.5 in C:\Users\gaura\anaconda3\Lib\site-packages (from dataudit==0.1.0) (3.0.0)
# Requirement already satisfied: openpyxl>=3.1 in C:\Users\gaura\anaconda3\Lib\site-packages (from dataudit==0.1.0) (3.1.5)
# Requirement already satisfied: et-xmlfile in C:\Users\gaura\anaconda3\Lib\site-packages (from openpyxl>=3.1->dataudit==0.1.0) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\gaura\anaconda3\Lib\site-packages (from pandas>=1.5->dataudit==0.1.0) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\gaura\anaconda3\Lib\site-packages (from pandas>=1.5->dataudit==0.1.0) (2023.3)
# Requirement already satisfied: six>=1.5 in C:\Users\gaura\anaconda3\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.5->dataudit==0.1.0) (1.16.0)
# Building wheels for collected packages: dataudit
#   Building wheel for dataudit (pyproject.toml): started
#   Building wheel for dataudit (pyproject.toml): finished with status 'done'
#   Created wheel for dataudit: filename=dataudit-0.1.0-py3-none-any.whl size=4856 sha256=02b73c2319e2ca07e1f3a03f73096c2ffdd0ab6caf8c6c53cbde4f2a11590ec5
#   Stored in directory: c:\users\gaura\appdata\local\pip\cache\wheels\b9\80\ea\014410fcaff78a0a62d7fb255d813dd5165edd358fd9265a52
# Successfully built dataudit
# Installing collected packages: dataudit
#   Attempting uninstall: dataudit
#     Found existing installation: dataudit 0.1.0
#     Uninstalling dataudit-0.1.0:
#       Successfully uninstalled dataudit-0.1.0
# Successfully installed dataudit-0.1.0

# %%
import pandas as pd
from dataudit import Profiler

# Option 1: DataFrame input
df = pd.read_csv("train.csv")
profiler = Profiler(df)

# Option 2: File path input
# profiler = Profiler("your_data.csv")
# profiler = Profiler("your_data.xlsx")
# profiler = Profiler("your_data.parquet")

overview = profiler.get_overview()
num_profile = profiler.profile_numerical()
cat_profile = profiler.profile_categorical()

report_path = profiler.export_report("Data_Audit_Report.xlsx")
print("Report created:", report_path)
# Out:
# Report created: Data_Audit_Report.xlsx
